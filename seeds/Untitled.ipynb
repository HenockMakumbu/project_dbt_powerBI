# %%
import pandas as pd
df = pd.read_csv('listings_airbnb_paris.csv')
df
# Out:
#                        id    host_id  \
# 0                41845069   43096459
# 1                40583432   17964689
# 2                27047642   20073379
# 3                53730419  142362342
# 4                26382127  133236836
# ...                   ...        ...
# 61701  798339949748697532    3524539
# 61702            44427677  358822038
# 61703  638111883184662732    3524539
# 61704            16789585   47639591
# 61705            50605885  373702608
#
#                                                     name  bedroom  bed  bath  \
# 0      Home in Paris · ★5.0 · 4 Bedrooms · 4 beds · 5...      4.0  4.0   5.0
# 1      Rental unit in Paris · ★4.57 · 1 Bedroom · 2 b...      1.0  2.0   1.0
# 2        Loft in Paris · 2 Bedrooms · 2 beds · 2.5 baths      2.0  2.0   2.5
# 3      Condo in Paris · ★4.69 · 1 Bedroom · 1 bed · 1...      1.0  1.0   1.0
# 4      Rental unit in Paris · ★4.93 · 1 Bedroom · 1 b...      1.0  1.0   1.0
# ...

# %%
df['license'][2]
# Out:
# '"Available with a mobility lease only (""bail mobilité"")"'
